# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import cv2

# %%
df = pd.read_csv('./labels.csv')
df
# Out:
#                                              filepath  xmin  xmax  ymin  ymax
# 0   .\Desktop\image processing project\Datasource\...   736  1218   505   898
# 1   .\Desktop\image processing project\Datasource\...   579  1082   207   640
# 2   .\Desktop\image processing project\Datasource\...   899  1157   394   580
# 3   .\Desktop\image processing project\Datasource\...   651   887   268   456
# 4   .\Desktop\image processing project\Datasource\...   833  1091   512   725
# 5   .\Desktop\image processing project\Datasource\...   773  1006   506   739
# 6   .\Desktop\image processing project\Datasource\...   803  1086   516   799
# 7   .\Desktop\image processing project\Datasource\...   776  1063   445   732
# 8   .\Desktop\image processing project\Datasource\...   776   987   432   643
# 9   .\Desktop\image processing project\Datasource\...   780  1095   454   769
# 10  .\Desktop\image processing project\Datasource\...  1032  1333   335   636
# 11  .\Desktop\image processing project\Datasource\...   532  1062   804  1287
# 12  .\Desktop\image processing project\Datasource\...  1021  1317   458   754
# 13  .\Desktop\image processing project\Datasource\...   707   979   160   432
# 14  .\Desktop\image processing project\Datasource\...   842  1172   451   781
# 15  .\Desktop\image processing project\Datasource\...  1016  1281   308   573
# 16  .\Desktop\image processing project\Datasource\...   817  1108   325   616
# 17  .\Desktop\image processing project\Datasource\...   606   894   242   530
# 18  .\Desktop\image processing project\Datasource\...   841  1067   517   743
# 19  .\Desktop\image processing project\Datasource\...   661   974   441   754
# 20  .\Desktop\image processing project\Datasource\...   942  1198    90   346
# 21  .\Desktop\image processing project\Datasource\...   847  1129   368   650
# 22  .\Desktop\image processing project\Datasource\...   914  1402   617  1024
# 23  .\Desktop\image processing project\Datasource\...   877  1172   235   530
# 24  .\Desktop\image processing project\Datasource\...   802  1321   940  1380
# 25  .\Desktop\image processing project\Datasource\...  1093  1615   922  1380
# 26  .\Desktop\image processing project\Datasource\...   945  1395   477   885
# 27  .\Desktop\image processing project\Datasource\...   883  1389   773  1208
# 28  .\Desktop\image processing project\Datasource\...   816  1335   880  1346
# 29  .\Desktop\image processing project\Datasource\...   892  1406   903  1334

# %%
import xml.etree.ElementTree as xet

# %%
def getFilename (filename):
    filename_image = xet.parse(filename).getroot().find('filename').text
    filepath_image = os.path.join('./Desktop/image processing project/Datasource',filename_image)
    return filepath_image

# %%
getFilename(df['filepath'][0])
# Out:
# './Desktop/image processing project/Datasource\\N1.png'

# %%
df['filepath'].apply(getFilename)
# Out:
# 0     ./Desktop/image processing project/Datasource\...
# 1     ./Desktop/image processing project/Datasource\...
# 2     ./Desktop/image processing project/Datasource\...
# 3     ./Desktop/image processing project/Datasource\...
# 4     ./Desktop/image processing project/Datasource\...
# 5     ./Desktop/image processing project/Datasource\...
# 6     ./Desktop/image processing project/Datasource\...
# 7     ./Desktop/image processing project/Datasource\...
# 8     ./Desktop/image processing project/Datasource\...
# 9     ./Desktop/image processing project/Datasource\...
# 10    ./Desktop/image processing project/Datasource\...
# 11    ./Desktop/image processing project/Datasource\...
# 12    ./Desktop/image processing project/Datasource\...
# 13    ./Desktop/image processing project/Datasource\...
# 14    ./Desktop/image processing project/Datasource\...
# 15    ./Desktop/image processing project/Datasource\...
# 16    ./Desktop/image processing project/Datasource\...
# 17    ./Desktop/image processing project/Datasource\...
# 18    ./Desktop/image processing project/Datasource\...
# 19    ./Desktop/image processing project/Datasource\...
# 20    ./Desktop/image processing project/Datasource\...
# 21    ./Desktop/image processing project/Datasource\...
# 22    ./Desktop/image processing project/Datasource\...
# 23    ./Desktop/image processing project/Datasource\...
# 24    ./Desktop/image processing project/Datasource\...
# 25    ./Desktop/image processing project/Datasource\...
# 26    ./Desktop/image processing project/Datasource\...
# 27    ./Desktop/image processing project/Datasource\...
# 28    ./Desktop/image processing project/Datasource\...
# 29    ./Desktop/image processing project/Datasource\...
# Name: filepath, dtype: object

# %%
image_path = list(df['filepath'].apply(getFilename))
image_path
# Out:
# ['./Desktop/image processing project/Datasource\\N1.png',
#  './Desktop/image processing project/Datasource\\N10.png',
#  './Desktop/image processing project/Datasource\\N11.png',
#  './Desktop/image processing project/Datasource\\N12.png',
#  './Desktop/image processing project/Datasource\\N13.png',
#  './Desktop/image processing project/Datasource\\N14.png',
#  './Desktop/image processing project/Datasource\\N15.png',
#  './Desktop/image processing project/Datasource\\N16.png',
#  './Desktop/image processing project/Datasource\\N17.png',
#  './Desktop/image processing project/Datasource\\N18.png',
#  './Desktop/image processing project/Datasource\\N19.png',
#  './Desktop/image processing project/Datasource\\N2.png',
#  './Desktop/image processing project/Datasource\\N20.png',
#  './Desktop/image processing project/Datasource\\N21.png',
#  './Desktop/image processing project/Datasource\\N22.png',
#  './Desktop/image processing project/Datasource\\N23.png',
#  './Desktop/image processing project/Datasource\\N24.png',
#  './Desktop/image processing project/Datasource\\N25.png',
#  './Desktop/image processing project/Datasource\\N26.png',
#  './Desktop/image processing project/Datasource\\N27.png',
#  './Desktop/image processing project/Datasource\\N28.png',
#  './Desktop/image processing project/Datasource\\N29.png',
#  './Desktop/image processing project/Datasource\\N3.png',
#  './Desktop/image processing project/Datasource\\N30.png',
#  './Desktop/image processing project/Datasource\\N4.png',
#  './Desktop/image processing project/Datasource\\N5.png',
#  './Desktop/image processing project/Datasource\\N6.png',
#  './Desktop/image processing project/Datasource\\N7.png',
#  './Desktop/image processing project/Datasource\\N8.png',
#  './Desktop/image processing project/Datasource\\N9.png']

# %%
#### pre process

# %%
from sklearn.model_selection import train_test_split

# %%
labels = df.iloc[:,1:].values
labels[0]
# Out:
# array([ 736, 1218,  505,  898], dtype=int64)

# %%
from tensorflow.keras.preprocessing.image  import load_img, img_to_array

# %%
data = []
output =[]
for ind in range(len(image_path)): 
    image = image_path[ind]
    img_arr = cv2.imread(image)
    h,w,d = img_arr.shape
    # Preprocess
    load_image = load_img(image, target_size = (224,224))
    load_image_arr = img_to_array(load_image)
    #normalization
    norm_load_image_arr = load_image_arr/255
    xmin, xmax, ymin, ymax = labels[ind]
    nxmin ,nxmax = xmin/w, xmax/w
    nymin ,nymax = ymin/h, ymax/h
    label_norm = (nxmin,nxmax,nymin, nymax)
    data.append(norm_load_image_arr)
    output.append(label_norm)

# %%
x = np.array(data, dtype = np.float32)
y = np.array(output, dtype = np.float32)

# %%
x.shape, y.shape
# Out:
# ((30, 224, 224, 3), (30, 4))

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, train_size = 0.8, random_state = 0)
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((24, 224, 224, 3), (6, 224, 224, 3), (24, 4), (6, 4))

# %%
from tensorflow.keras.applications import MobileNetV2, InceptionV3, InceptionResNetV2
from tensorflow.keras.layers import Dense, Dropout, Flatten, Input
from tensorflow.keras.models import Model
import tensorflow as tf

# %%
inception_resnet = InceptionResNetV2(weights = "imagenet", include_top = False, input_tensor = Input(shape = (224,224,3)))
inception_resnet.trainable = False
#------------ Input layer model
headmodel = inception_resnet.output
headmodel = Flatten()(headmodel)
headmodel = Dense(500, activation = "relu")(headmodel)
headmodel = Dense(500, activation = "relu")(headmodel)
headmodel = Dense(4, activation = 'sigmoid')(headmodel)
#------------ Model
model = Model(inception_resnet.input, outputs = headmodel)

# %%
# Model compile
model.compile(loss = 'mse', optimizer = tf.keras.optimizers.Adam(learning_rate = 1e-4))
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d_812 (Conv2D)            (None, 111, 111, 32  864         ['input_5[0][0]']
#                                 )
#
#  batch_normalization_812 (Batch  (None, 111, 111, 32  96         ['conv2d_812[0][0]']
#  Normalization)                 )
#
#  activation_812 (Activation)    (None, 111, 111, 32  0           ['batch_normalization_812[0][0]']
#                                 )
#
#  conv2d_813 (Conv2D)            (None, 109, 109, 32  9216        ['activation_812[0][0]']
#                                 )
#
#  batch_normalization_813 (Batch  (None, 109, 109, 32  96         ['conv2d_813[0][0]']
#  Normalization)                 )
#
#  activation_813 (Activation)    (None, 109, 109, 32  0           ['batch_normalization_813[0][0]']
#                                 )
#
#  conv2d_814 (Conv2D)            (None, 109, 109, 64  18432       ['activation_813[0][0]']
#                                 )
#
#  batch_normalization_814 (Batch  (None, 109, 109, 64  192        ['conv2d_814[0][0]']
#  Normalization)                 )
#
#  activation_814 (Activation)    (None, 109, 109, 64  0           ['batch_normalization_814[0][0]']
#                                 )
#
#  max_pooling2d_16 (MaxPooling2D  (None, 54, 54, 64)  0           ['activation_814[0][0]']
#  )
#
#  conv2d_815 (Conv2D)            (None, 54, 54, 80)   5120        ['max_pooling2d_16[0][0]']
#
#  batch_normalization_815 (Batch  (None, 54, 54, 80)  240         ['conv2d_815[0][0]']
#  Normalization)
#
#  activation_815 (Activation)    (None, 54, 54, 80)   0           ['batch_normalization_815[0][0]']
#
#  conv2d_816 (Conv2D)            (None, 52, 52, 192)  138240      ['activation_815[0][0]']
#
#  batch_normalization_816 (Batch  (None, 52, 52, 192)  576        ['conv2d_816[0][0]']
#  Normalization)
#
#  activation_816 (Activation)    (None, 52, 52, 192)  0           ['batch_normalization_816[0][0]']
#
#  max_pooling2d_17 (MaxPooling2D  (None, 25, 25, 192)  0          ['activation_816[0][0]']
#  )
#
#  conv2d_820 (Conv2D)            (None, 25, 25, 64)   12288       ['max_pooling2d_17[0][0]']
#
#  batch_normalization_820 (Batch  (None, 25, 25, 64)  192         ['conv2d_820[0][0]']
#  Normalization)
#
#  activation_820 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_820[0][0]']
#
#  conv2d_818 (Conv2D)            (None, 25, 25, 48)   9216        ['max_pooling2d_17[0][0]']
#
#  conv2d_821 (Conv2D)            (None, 25, 25, 96)   55296       ['activation_820[0][0]']
#
#  batch_normalization_818 (Batch  (None, 25, 25, 48)  144         ['conv2d_818[0][0]']
#  Normalization)
#
#  batch_normalization_821 (Batch  (None, 25, 25, 96)  288         ['conv2d_821[0][0]']
#  Normalization)
#
#  activation_818 (Activation)    (None, 25, 25, 48)   0           ['batch_normalization_818[0][0]']
#
#  activation_821 (Activation)    (None, 25, 25, 96)   0           ['batch_normalization_821[0][0]']
#
#  average_pooling2d_4 (AveragePo  (None, 25, 25, 192)  0          ['max_pooling2d_17[0][0]']
#  oling2D)
#
#  conv2d_817 (Conv2D)            (None, 25, 25, 96)   18432       ['max_pooling2d_17[0][0]']
#
#  conv2d_819 (Conv2D)            (None, 25, 25, 64)   76800       ['activation_818[0][0]']
#
#  conv2d_822 (Conv2D)            (None, 25, 25, 96)   82944       ['activation_821[0][0]']
#
#  conv2d_823 (Conv2D)            (None, 25, 25, 64)   12288       ['average_pooling2d_4[0][0]']
#
#  batch_normalization_817 (Batch  (None, 25, 25, 96)  288         ['conv2d_817[0][0]']
#  Normalization)
#
#  batch_normalization_819 (Batch  (None, 25, 25, 64)  192         ['conv2d_819[0][0]']
#  Normalization)
#
#  batch_normalization_822 (Batch  (None, 25, 25, 96)  288         ['conv2d_822[0][0]']
#  Normalization)
#
#  batch_normalization_823 (Batch  (None, 25, 25, 64)  192         ['conv2d_823[0][0]']
#  Normalization)
#
#  activation_817 (Activation)    (None, 25, 25, 96)   0           ['batch_normalization_817[0][0]']
#
#  activation_819 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_819[0][0]']
#
#  activation_822 (Activation)    (None, 25, 25, 96)   0           ['batch_normalization_822[0][0]']
#
#  activation_823 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_823[0][0]']
#
#  mixed_5b (Concatenate)         (None, 25, 25, 320)  0           ['activation_817[0][0]',
#                                                                   'activation_819[0][0]',
#                                                                   'activation_822[0][0]',
#                                                                   'activation_823[0][0]']
#
#  conv2d_827 (Conv2D)            (None, 25, 25, 32)   10240       ['mixed_5b[0][0]']
#
#  batch_normalization_827 (Batch  (None, 25, 25, 32)  96          ['conv2d_827[0][0]']
#  Normalization)
#
#  activation_827 (Activation)    (None, 25, 25, 32)   0           ['batch_normalization_827[0][0]']
#
#  conv2d_825 (Conv2D)            (None, 25, 25, 32)   10240       ['mixed_5b[0][0]']
#
#  conv2d_828 (Conv2D)            (None, 25, 25, 48)   13824       ['activation_827[0][0]']
#
#  batch_normalization_825 (Batch  (None, 25, 25, 32)  96          ['conv2d_825[0][0]']
#  Normalization)
#
#  batch_normalization_828 (Batch  (None, 25, 25, 48)  144         ['conv2d_828[0][0]']
#  Normalization)
#
#  activation_825 (Activation)    (None, 25, 25, 32)   0           ['batch_normalization_825[0][0]']
#
#  activation_828 (Activation)    (None, 25, 25, 48)   0           ['batch_normalization_828[0][0]']
#
#  conv2d_824 (Conv2D)            (None, 25, 25, 32)   10240       ['mixed_5b[0][0]']
#
#  conv2d_826 (Conv2D)            (None, 25, 25, 32)   9216        ['activation_825[0][0]']
#
#  conv2d_829 (Conv2D)            (None, 25, 25, 64)   27648       ['activation_828[0][0]']
#
#  batch_normalization_824 (Batch  (None, 25, 25, 32)  96          ['conv2d_824[0][0]']
#  Normalization)
#
#  batch_normalization_826 (Batch  (None, 25, 25, 32)  96          ['conv2d_826[0][0]']
#  Normalization)
#
#  batch_normalization_829 (Batch  (None, 25, 25, 64)  192         ['conv2d_829[0][0]']
#  Normalization)
#
#  activation_824 (Activation)    (None, 25, 25, 32)   0           ['batch_normalization_824[0][0]']
#
#  activation_826 (Activation)    (None, 25, 25, 32)   0           ['batch_normalization_826[0][0]']
#
#  activation_829 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_829[0][0]']
#
#  block35_1_mixed (Concatenate)  (None, 25, 25, 128)  0           ['activation_824[0][0]',
#                                                                   'activation_826[0][0]',
#                                                                   'activation_829[0][0]']
#
#  block35_1_conv (Conv2D)        (None, 25, 25, 320)  41280       ['block35_1_mixed[0][0]']
#
#  block35_1 (Lambda)             (None, 25, 25, 320)  0           ['mixed_5b[0][0]',
#                                                                   'block35_1_conv[0][0]']
#
#  block35_1_ac (Activation)      (None, 25, 25, 320)  0           ['block35_1[0][0]']
#
#  conv2d_833 (Conv2D)            (None, 25, 25, 32)   10240       ['block35_1_ac[0][0]']
#
#  batch_normalization_833 (Batch  (None, 25, 25, 32)  96          ['conv2d_833[0][0]']
#  Normalization)
#
#  activation_833 (Activation)    (None, 25, 25, 32)   0           ['batch_normalization_833[0][0]']
#
#  conv2d_831 (Conv2D)            (None, 25, 25, 32)   10240       ['block35_1_ac[0][0]']
#
#  conv2d_834 (Conv2D)            (None, 25, 25, 48)   13824       ['activation_833[0][0]']
#
#  batch_normalization_831 (Batch  (None, 25, 25, 32)  96          ['conv2d_831[0][0]']
#  Normalization)
#
#  batch_normalization_834 (Batch  (None, 25, 25, 48)  144         ['conv2d_834[0][0]']
#  Normalization)
#
#  activation_831 (Activation)    (None, 25, 25, 32)   0           ['batch_normalization_831[0][0]']
#
#  activation_834 (Activation)    (None, 25, 25, 48)   0           ['batch_normalization_834[0][0]']
#
#  conv2d_830 (Conv2D)            (None, 25, 25, 32)   10240       ['block35_1_ac[0][0]']
#
#  conv2d_832 (Conv2D)            (None, 25, 25, 32)   9216        ['activation_831[0][0]']
#
#  conv2d_835 (Conv2D)            (None, 25, 25, 64)   27648       ['activation_834[0][0]']
#
#  batch_normalization_830 (Batch  (None, 25, 25, 32)  96          ['conv2d_830[0][0]']
#  Normalization)
#
#  batch_normalization_832 (Batch  (None, 25, 25, 32)  96          ['conv2d_832[0][0]']
#  Normalization)
#
#  batch_normalization_835 (Batch  (None, 25, 25, 64)  192         ['conv2d_835[0][0]']
#  Normalization)
#
#  activation_830 (Activation)    (None, 25, 25, 32)   0           ['batch_normalization_830[0][0]']
#
#  activation_832 (Activation)    (None, 25, 25, 32)   0           ['batch_normalization_832[0][0]']
#
#  activation_835 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_835[0][0]']
#
#  block35_2_mixed (Concatenate)  (None, 25, 25, 128)  0           ['activation_830[0][0]',
#                                                                   'activation_832[0][0]',
#                                                                   'activation_835[0][0]']
#
#  block35_2_conv (Conv2D)        (None, 25, 25, 320)  41280       ['block35_2_mixed[0][0]']
#
#  block35_2 (Lambda)             (None, 25, 25, 320)  0           ['block35_1_ac[0][0]',
#                                                                   'block35_2_conv[0][0]']
#
#  block35_2_ac (Activation)      (None, 25, 25, 320)  0           ['block35_2[0][0]']
#
#  conv2d_839 (Conv2D)            (None, 25, 25, 32)   10240       ['block35_2_ac[0][0]']
#
#  batch_normalization_839 (Batch  (None, 25, 25, 32)  96          ['conv2d_839[0][0]']
#  Normalization)
#
#  activation_839 (Activation)    (None, 25, 25, 32)   0           ['batch_normalization_839[0][0]']
#
#  conv2d_837 (Conv2D)            (None, 25, 25, 32)   10240       ['block35_2_ac[0][0]']
#
#  conv2d_840 (Conv2D)            (None, 25, 25, 48)   13824       ['activation_839[0][0]']
#
#  batch_normalization_837 (Batch  (None, 25, 25, 32)  96          ['conv2d_837[0][0]']
#  Normalization)
#
#  batch_normalization_840 (Batch  (None, 25, 25, 48)  144         ['conv2d_840[0][0]']
#  Normalization)
#
#  activation_837 (Activation)    (None, 25, 25, 32)   0           ['batch_normalization_837[0][0]']
#
#  activation_840 (Activation)    (None, 25, 25, 48)   0           ['batch_normalization_840[0][0]']
#
#  conv2d_836 (Conv2D)            (None, 25, 25, 32)   10240       ['block35_2_ac[0][0]']
#
#  conv2d_838 (Conv2D)            (None, 25, 25, 32)   9216        ['activation_837[0][0]']
#
#  conv2d_841 (Conv2D)            (None, 25, 25, 64)   27648       ['activation_840[0][0]']
#
#  batch_normalization_836 (Batch  (None, 25, 25, 32)  96          ['conv2d_836[0][0]']
#  Normalization)
#
#  batch_normalization_838 (Batch  (None, 25, 25, 32)  96          ['conv2d_838[0][0]']
#  Normalization)
#
#  batch_normalization_841 (Batch  (None, 25, 25, 64)  192         ['conv2d_841[0][0]']
#  Normalization)
#
#  activation_836 (Activation)    (None, 25, 25, 32)   0           ['batch_normalization_836[0][0]']
#
#  activation_838 (Activation)    (None, 25, 25, 32)   0           ['batch_normalization_838[0][0]']
#
#  activation_841 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_841[0][0]']
#
#  block35_3_mixed (Concatenate)  (None, 25, 25, 128)  0           ['activation_836[0][0]',
#                                                                   'activation_838[0][0]',
#                                                                   'activation_841[0][0]']
#
#  block35_3_conv (Conv2D)        (None, 25, 25, 320)  41280       ['block35_3_mixed[0][0]']
#
#  block35_3 (Lambda)             (None, 25, 25, 320)  0           ['block35_2_ac[0][0]',
#                                                                   'block35_3_conv[0][0]']
#
#  block35_3_ac (Activation)      (None, 25, 25, 320)  0           ['block35_3[0][0]']
#
#  conv2d_845 (Conv2D)            (None, 25, 25, 32)   10240       ['block35_3_ac[0][0]']
#
#  batch_normalization_845 (Batch  (None, 25, 25, 32)  96          ['conv2d_845[0][0]']
#  Normalization)
#
#  activation_845 (Activation)    (None, 25, 25, 32)   0           ['batch_normalization_845[0][0]']
#
#  conv2d_843 (Conv2D)            (None, 25, 25, 32)   10240       ['block35_3_ac[0][0]']
#
#  conv2d_846 (Conv2D)            (None, 25, 25, 48)   13824       ['activation_845[0][0]']
#
#  batch_normalization_843 (Batch  (None, 25, 25, 32)  96          ['conv2d_843[0][0]']
#  Normalization)
#
#  batch_normalization_846 (Batch  (None, 25, 25, 48)  144         ['conv2d_846[0][0]']
#  Normalization)
#
#  activation_843 (Activation)    (None, 25, 25, 32)   0           ['batch_normalization_843[0][0]']
#
#  activation_846 (Activation)    (None, 25, 25, 48)   0           ['batch_normalization_846[0][0]']
#
#  conv2d_842 (Conv2D)            (None, 25, 25, 32)   10240       ['block35_3_ac[0][0]']
#
#  conv2d_844 (Conv2D)            (None, 25, 25, 32)   9216        ['activation_843[0][0]']
#
#  conv2d_847 (Conv2D)            (None, 25, 25, 64)   27648       ['activation_846[0][0]']
#
#  batch_normalization_842 (Batch  (None, 25, 25, 32)  96          ['conv2d_842[0][0]']
#  Normalization)
#
#  batch_normalization_844 (Batch  (None, 25, 25, 32)  96          ['conv2d_844[0][0]']
#  Normalization)
#
#  batch_normalization_847 (Batch  (None, 25, 25, 64)  192         ['conv2d_847[0][0]']
#  Normalization)
#
#  activation_842 (Activation)    (None, 25, 25, 32)   0           ['batch_normalization_842[0][0]']
#
#  activation_844 (Activation)    (None, 25, 25, 32)   0           ['batch_normalization_844[0][0]']
#
#  activation_847 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_847[0][0]']
#
#  block35_4_mixed (Concatenate)  (None, 25, 25, 128)  0           ['activation_842[0][0]',
#                                                                   'activation_844[0][0]',
#                                                                   'activation_847[0][0]']
#
#  block35_4_conv (Conv2D)        (None, 25, 25, 320)  41280       ['block35_4_mixed[0][0]']
#
#  block35_4 (Lambda)             (None, 25, 25, 320)  0           ['block35_3_ac[0][0]',
#                                                                   'block35_4_conv[0][0]']
#
#  block35_4_ac (Activation)      (None, 25, 25, 320)  0           ['block35_4[0][0]']
#
#  conv2d_851 (Conv2D)            (None, 25, 25, 32)   10240       ['block35_4_ac[0][0]']
#
#  batch_normalization_851 (Batch  (None, 25, 25, 32)  96          ['conv2d_851[0][0]']
#  Normalization)
#
#  activation_851 (Activation)    (None, 25, 25, 32)   0           ['batch_normalization_851[0][0]']
#
#  conv2d_849 (Conv2D)            (None, 25, 25, 32)   10240       ['block35_4_ac[0][0]']
#
#  conv2d_852 (Conv2D)            (None, 25, 25, 48)   13824       ['activation_851[0][0]']
#
#  batch_normalization_849 (Batch  (None, 25, 25, 32)  96          ['conv2d_849[0][0]']
#  Normalization)
#
#  batch_normalization_852 (Batch  (None, 25, 25, 48)  144         ['conv2d_852[0][0]']
#  Normalization)
#
#  activation_849 (Activation)    (None, 25, 25, 32)   0           ['batch_normalization_849[0][0]']
#
#  activation_852 (Activation)    (None, 25, 25, 48)   0           ['batch_normalization_852[0][0]']
#
#  conv2d_848 (Conv2D)            (None, 25, 25, 32)   10240       ['block35_4_ac[0][0]']
#
#  conv2d_850 (Conv2D)            (None, 25, 25, 32)   9216        ['activation_849[0][0]']
#
#  conv2d_853 (Conv2D)            (None, 25, 25, 64)   27648       ['activation_852[0][0]']
#
#  batch_normalization_848 (Batch  (None, 25, 25, 32)  96          ['conv2d_848[0][0]']
#  Normalization)
#
#  batch_normalization_850 (Batch  (None, 25, 25, 32)  96          ['conv2d_850[0][0]']
#  Normalization)
#
#  batch_normalization_853 (Batch  (None, 25, 25, 64)  192         ['conv2d_853[0][0]']
#  Normalization)
#
#  activation_848 (Activation)    (None, 25, 25, 32)   0           ['batch_normalization_848[0][0]']
#
#  activation_850 (Activation)    (None, 25, 25, 32)   0           ['batch_normalization_850[0][0]']
#
#  activation_853 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_853[0][0]']
#
#  block35_5_mixed (Concatenate)  (None, 25, 25, 128)  0           ['activation_848[0][0]',
#                                                                   'activation_850[0][0]',
#                                                                   'activation_853[0][0]']
#
#  block35_5_conv (Conv2D)        (None, 25, 25, 320)  41280       ['block35_5_mixed[0][0]']
#
#  block35_5 (Lambda)             (None, 25, 25, 320)  0           ['block35_4_ac[0][0]',
#                                                                   'block35_5_conv[0][0]']
#
#  block35_5_ac (Activation)      (None, 25, 25, 320)  0           ['block35_5[0][0]']
#
#  conv2d_857 (Conv2D)            (None, 25, 25, 32)   10240       ['block35_5_ac[0][0]']
#
#  batch_normalization_857 (Batch  (None, 25, 25, 32)  96          ['conv2d_857[0][0]']
#  Normalization)
#
#  activation_857 (Activation)    (None, 25, 25, 32)   0           ['batch_normalization_857[0][0]']
#
#  conv2d_855 (Conv2D)            (None, 25, 25, 32)   10240       ['block35_5_ac[0][0]']
#
#  conv2d_858 (Conv2D)            (None, 25, 25, 48)   13824       ['activation_857[0][0]']
#
#  batch_normalization_855 (Batch  (None, 25, 25, 32)  96          ['conv2d_855[0][0]']
#  Normalization)
#
#  batch_normalization_858 (Batch  (None, 25, 25, 48)  144         ['conv2d_858[0][0]']
#  Normalization)
#
#  activation_855 (Activation)    (None, 25, 25, 32)   0           ['batch_normalization_855[0][0]']
#
#  activation_858 (Activation)    (None, 25, 25, 48)   0           ['batch_normalization_858[0][0]']
#
#  conv2d_854 (Conv2D)            (None, 25, 25, 32)   10240       ['block35_5_ac[0][0]']
#
#  conv2d_856 (Conv2D)            (None, 25, 25, 32)   9216        ['activation_855[0][0]']
#
#  conv2d_859 (Conv2D)            (None, 25, 25, 64)   27648       ['activation_858[0][0]']
#
#  batch_normalization_854 (Batch  (None, 25, 25, 32)  96          ['conv2d_854[0][0]']
#  Normalization)
#
#  batch_normalization_856 (Batch  (None, 25, 25, 32)  96          ['conv2d_856[0][0]']
#  Normalization)
#
#  batch_normalization_859 (Batch  (None, 25, 25, 64)  192         ['conv2d_859[0][0]']
#  Normalization)
#
#  activation_854 (Activation)    (None, 25, 25, 32)   0           ['batch_normalization_854[0][0]']
#
#  activation_856 (Activation)    (None, 25, 25, 32)   0           ['batch_normalization_856[0][0]']
#
#  activation_859 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_859[0][0]']
#
#  block35_6_mixed (Concatenate)  (None, 25, 25, 128)  0           ['activation_854[0][0]',
#                                                                   'activation_856[0][0]',
#                                                                   'activation_859[0][0]']
#
#  block35_6_conv (Conv2D)        (None, 25, 25, 320)  41280       ['block35_6_mixed[0][0]']
#
#  block35_6 (Lambda)             (None, 25, 25, 320)  0           ['block35_5_ac[0][0]',
#                                                                   'block35_6_conv[0][0]']
#
#  block35_6_ac (Activation)      (None, 25, 25, 320)  0           ['block35_6[0][0]']
#
#  conv2d_863 (Conv2D)            (None, 25, 25, 32)   10240       ['block35_6_ac[0][0]']
#
#  batch_normalization_863 (Batch  (None, 25, 25, 32)  96          ['conv2d_863[0][0]']
#  Normalization)
#
#  activation_863 (Activation)    (None, 25, 25, 32)   0           ['batch_normalization_863[0][0]']
#
#  conv2d_861 (Conv2D)            (None, 25, 25, 32)   10240       ['block35_6_ac[0][0]']
#
#  conv2d_864 (Conv2D)            (None, 25, 25, 48)   13824       ['activation_863[0][0]']
#
#  batch_normalization_861 (Batch  (None, 25, 25, 32)  96          ['conv2d_861[0][0]']
#  Normalization)
#
#  batch_normalization_864 (Batch  (None, 25, 25, 48)  144         ['conv2d_864[0][0]']
#  Normalization)
#
#  activation_861 (Activation)    (None, 25, 25, 32)   0           ['batch_normalization_861[0][0]']
#
#  activation_864 (Activation)    (None, 25, 25, 48)   0           ['batch_normalization_864[0][0]']
#
#  conv2d_860 (Conv2D)            (None, 25, 25, 32)   10240       ['block35_6_ac[0][0]']
#
#  conv2d_862 (Conv2D)            (None, 25, 25, 32)   9216        ['activation_861[0][0]']
#
#  conv2d_865 (Conv2D)            (None, 25, 25, 64)   27648       ['activation_864[0][0]']
#
#  batch_normalization_860 (Batch  (None, 25, 25, 32)  96          ['conv2d_860[0][0]']
#  Normalization)
#
#  batch_normalization_862 (Batch  (None, 25, 25, 32)  96          ['conv2d_862[0][0]']
#  Normalization)
#
#  batch_normalization_865 (Batch  (None, 25, 25, 64)  192         ['conv2d_865[0][0]']
#  Normalization)
#
#  activation_860 (Activation)    (None, 25, 25, 32)   0           ['batch_normalization_860[0][0]']
#
#  activation_862 (Activation)    (None, 25, 25, 32)   0           ['batch_normalization_862[0][0]']
#
#  activation_865 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_865[0][0]']
#
#  block35_7_mixed (Concatenate)  (None, 25, 25, 128)  0           ['activation_860[0][0]',
#                                                                   'activation_862[0][0]',
#                                                                   'activation_865[0][0]']
#
#  block35_7_conv (Conv2D)        (None, 25, 25, 320)  41280       ['block35_7_mixed[0][0]']
#
#  block35_7 (Lambda)             (None, 25, 25, 320)  0           ['block35_6_ac[0][0]',
#                                                                   'block35_7_conv[0][0]']
#
#  block35_7_ac (Activation)      (None, 25, 25, 320)  0           ['block35_7[0][0]']
#
#  conv2d_869 (Conv2D)            (None, 25, 25, 32)   10240       ['block35_7_ac[0][0]']
#
#  batch_normalization_869 (Batch  (None, 25, 25, 32)  96          ['conv2d_869[0][0]']
# ...
#  Normalization)
#
#  batch_normalization_1002 (Batc  (None, 5, 5, 256)   768         ['conv2d_1002[0][0]']
#  hNormalization)
#
#  activation_999 (Activation)    (None, 5, 5, 192)    0           ['batch_normalization_999[0][0]']
#  activation_1002 (Activation)   (None, 5, 5, 256)    0           ['batch_normalization_1002[0][0]'
#                                                                  ]
#
#  block8_7_mixed (Concatenate)   (None, 5, 5, 448)    0           ['activation_999[0][0]',
#                                                                   'activation_1002[0][0]']
#
#  block8_7_conv (Conv2D)         (None, 5, 5, 2080)   933920      ['block8_7_mixed[0][0]']
#
#  block8_7 (Lambda)              (None, 5, 5, 2080)   0           ['block8_6_ac[0][0]',
#                                                                   'block8_7_conv[0][0]']
#
#  block8_7_ac (Activation)       (None, 5, 5, 2080)   0           ['block8_7[0][0]']
#
#  conv2d_1004 (Conv2D)           (None, 5, 5, 192)    399360      ['block8_7_ac[0][0]']
#
#  batch_normalization_1004 (Batc  (None, 5, 5, 192)   576         ['conv2d_1004[0][0]']
#  hNormalization)
#
#  activation_1004 (Activation)   (None, 5, 5, 192)    0           ['batch_normalization_1004[0][0]'
#                                                                  ]
#
#  conv2d_1005 (Conv2D)           (None, 5, 5, 224)    129024      ['activation_1004[0][0]']
#
#  batch_normalization_1005 (Batc  (None, 5, 5, 224)   672         ['conv2d_1005[0][0]']
#  hNormalization)
#
#  activation_1005 (Activation)   (None, 5, 5, 224)    0           ['batch_normalization_1005[0][0]'
#                                                                  ]
#
#  conv2d_1003 (Conv2D)           (None, 5, 5, 192)    399360      ['block8_7_ac[0][0]']
#
#  conv2d_1006 (Conv2D)           (None, 5, 5, 256)    172032      ['activation_1005[0][0]']
#
#  batch_normalization_1003 (Batc  (None, 5, 5, 192)   576         ['conv2d_1003[0][0]']
#  hNormalization)
#
#  batch_normalization_1006 (Batc  (None, 5, 5, 256)   768         ['conv2d_1006[0][0]']
#  hNormalization)
#
#  activation_1003 (Activation)   (None, 5, 5, 192)    0           ['batch_normalization_1003[0][0]'
#                                                                  ]
#
#  activation_1006 (Activation)   (None, 5, 5, 256)    0           ['batch_normalization_1006[0][0]'
#                                                                  ]
#
#  block8_8_mixed (Concatenate)   (None, 5, 5, 448)    0           ['activation_1003[0][0]',
#                                                                   'activation_1006[0][0]']
#
#  block8_8_conv (Conv2D)         (None, 5, 5, 2080)   933920      ['block8_8_mixed[0][0]']
#
#  block8_8 (Lambda)              (None, 5, 5, 2080)   0           ['block8_7_ac[0][0]',
#                                                                   'block8_8_conv[0][0]']
#
#  block8_8_ac (Activation)       (None, 5, 5, 2080)   0           ['block8_8[0][0]']
#
#  conv2d_1008 (Conv2D)           (None, 5, 5, 192)    399360      ['block8_8_ac[0][0]']
#
#  batch_normalization_1008 (Batc  (None, 5, 5, 192)   576         ['conv2d_1008[0][0]']
#  hNormalization)
#
#  activation_1008 (Activation)   (None, 5, 5, 192)    0           ['batch_normalization_1008[0][0]'
#                                                                  ]
#
#  conv2d_1009 (Conv2D)           (None, 5, 5, 224)    129024      ['activation_1008[0][0]']
#
#  batch_normalization_1009 (Batc  (None, 5, 5, 224)   672         ['conv2d_1009[0][0]']
#  hNormalization)
#
#  activation_1009 (Activation)   (None, 5, 5, 224)    0           ['batch_normalization_1009[0][0]'
#                                                                  ]
#
#  conv2d_1007 (Conv2D)           (None, 5, 5, 192)    399360      ['block8_8_ac[0][0]']
#
#  conv2d_1010 (Conv2D)           (None, 5, 5, 256)    172032      ['activation_1009[0][0]']
#
#  batch_normalization_1007 (Batc  (None, 5, 5, 192)   576         ['conv2d_1007[0][0]']
#  hNormalization)
#
#  batch_normalization_1010 (Batc  (None, 5, 5, 256)   768         ['conv2d_1010[0][0]']
#  hNormalization)
#
#  activation_1007 (Activation)   (None, 5, 5, 192)    0           ['batch_normalization_1007[0][0]'
#                                                                  ]
#
#  activation_1010 (Activation)   (None, 5, 5, 256)    0           ['batch_normalization_1010[0][0]'
#                                                                  ]
#
#  block8_9_mixed (Concatenate)   (None, 5, 5, 448)    0           ['activation_1007[0][0]',
#                                                                   'activation_1010[0][0]']
#
#  block8_9_conv (Conv2D)         (None, 5, 5, 2080)   933920      ['block8_9_mixed[0][0]']
#
#  block8_9 (Lambda)              (None, 5, 5, 2080)   0           ['block8_8_ac[0][0]',
#                                                                   'block8_9_conv[0][0]']
#
#  block8_9_ac (Activation)       (None, 5, 5, 2080)   0           ['block8_9[0][0]']
#
#  conv2d_1012 (Conv2D)           (None, 5, 5, 192)    399360      ['block8_9_ac[0][0]']
#
#  batch_normalization_1012 (Batc  (None, 5, 5, 192)   576         ['conv2d_1012[0][0]']
#  hNormalization)
#
#  activation_1012 (Activation)   (None, 5, 5, 192)    0           ['batch_normalization_1012[0][0]'
#                                                                  ]
#
#  conv2d_1013 (Conv2D)           (None, 5, 5, 224)    129024      ['activation_1012[0][0]']
#
#  batch_normalization_1013 (Batc  (None, 5, 5, 224)   672         ['conv2d_1013[0][0]']
#  hNormalization)
#
#  activation_1013 (Activation)   (None, 5, 5, 224)    0           ['batch_normalization_1013[0][0]'
#                                                                  ]
#
#  conv2d_1011 (Conv2D)           (None, 5, 5, 192)    399360      ['block8_9_ac[0][0]']
#
#  conv2d_1014 (Conv2D)           (None, 5, 5, 256)    172032      ['activation_1013[0][0]']
#
#  batch_normalization_1011 (Batc  (None, 5, 5, 192)   576         ['conv2d_1011[0][0]']
#  hNormalization)
#
#  batch_normalization_1014 (Batc  (None, 5, 5, 256)   768         ['conv2d_1014[0][0]']
#  hNormalization)
#
#  activation_1011 (Activation)   (None, 5, 5, 192)    0           ['batch_normalization_1011[0][0]'
#                                                                  ]
#
#  activation_1014 (Activation)   (None, 5, 5, 256)    0           ['batch_normalization_1014[0][0]'
#                                                                  ]
#
#  block8_10_mixed (Concatenate)  (None, 5, 5, 448)    0           ['activation_1011[0][0]',
#                                                                   'activation_1014[0][0]']
#
#  block8_10_conv (Conv2D)        (None, 5, 5, 2080)   933920      ['block8_10_mixed[0][0]']
#
#  block8_10 (Lambda)             (None, 5, 5, 2080)   0           ['block8_9_ac[0][0]',
#                                                                   'block8_10_conv[0][0]']
#
#  conv_7b (Conv2D)               (None, 5, 5, 1536)   3194880     ['block8_10[0][0]']
#
#  conv_7b_bn (BatchNormalization  (None, 5, 5, 1536)  4608        ['conv_7b[0][0]']
#  )
#
#  conv_7b_ac (Activation)        (None, 5, 5, 1536)   0           ['conv_7b_bn[0][0]']
#
#  flatten_3 (Flatten)            (None, 38400)        0           ['conv_7b_ac[0][0]']
#
#  dense_9 (Dense)                (None, 500)          19200500    ['flatten_3[0][0]']
#
#  dense_10 (Dense)               (None, 500)          250500      ['dense_9[0][0]']
#
#  dense_11 (Dense)               (None, 4)            2004        ['dense_10[0][0]']
#
# ==================================================================================================
# Total params: 73,789,740
# Trainable params: 19,453,004
# Non-trainable params: 54,336,736
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.callbacks import TensorBoard

# %%
tfb = TensorBoard('object_detection')

# %%
history = model.fit(x = x_train, y = y_train, batch_size = 10, epochs = 100, validation_data = (x_test, y_test))
# Out:
# Epoch 1/100
# 3/3 [==============================] - 11s 2s/step - loss: 0.1451 - val_loss: 0.1954
# Epoch 2/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.1968 - val_loss: 0.1915
# Epoch 3/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.2013 - val_loss: 0.1895
# Epoch 4/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.2019 - val_loss: 0.1870
# Epoch 5/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.1892 - val_loss: 0.1608
# Epoch 6/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.1634 - val_loss: 0.1081
# Epoch 7/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.1141 - val_loss: 0.1348
# Epoch 8/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.1263 - val_loss: 0.1347
# Epoch 9/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.1246 - val_loss: 0.1333
# Epoch 10/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.1238 - val_loss: 0.1255
# Epoch 11/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.1289 - val_loss: 0.1365
# Epoch 12/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.1226 - val_loss: 0.1301
# Epoch 13/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.
100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0032 - val_loss: 0.0084
# Epoch 78/100
# 3/3 [==============================] - 3s 1s/step - loss: 0.0037 - val_loss: 0.0074
# Epoch 79/100
# 3/3 [==============================] - 3s 1s/step - loss: 0.0035 - val_loss: 0.0060
# Epoch 80/100
# 3/3 [==============================] - 3s 1s/step - loss: 0.0027 - val_loss: 0.0061
# Epoch 81/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0039 - val_loss: 0.0081
# Epoch 82/100
# 3/3 [==============================] - 3s 1s/step - loss: 0.0046 - val_loss: 0.0081
# Epoch 83/100
# 3/3 [==============================] - 3s 1s/step - loss: 0.0041 - val_loss: 0.0090
# Epoch 84/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0059 - val_loss: 0.0071
# Epoch 85/100
# 3/3 [==============================] - 3s 1s/step - loss: 0.0048 - val_loss: 0.0083
# Epoch 86/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0069 - val_loss: 0.0075
# Epoch 87/100
# 3/3 [==============================] - 3s 1s/step - loss: 0.0078 - val_loss: 0.0089
# Epoch 88/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0059 - val_loss: 0.0074
# Epoch 89/100
# 3/3 [==============================] - 3s 1s/step - loss: 0.0065 - val_loss: 0.0072
# Epoch 90/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0053 - val_loss: 0.0094
# Epoch 91/100
# 3/3 [==============================] - 3s 1s/step - loss: 0.0051 - val_loss: 0.0054
# Epoch 92/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0040 - val_loss: 0.0053
# Epoch 93/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0033 - val_loss: 0.0068
# Epoch 94/100
# 3/3 [==============================] - 3s 1s/step - loss: 0.0019 - val_loss: 0.0051
# Epoch 95/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0015 - val_loss: 0.0070
# Epoch 96/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0019 - val_loss: 0.0060
# Epoch 97/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0016 - val_loss: 0.0049
# Epoch 98/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0012 - val_loss: 0.0069
# Epoch 99/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0014 - val_loss: 0.0056
# Epoch 100/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.0013 - val_loss: 0.0067

# %%
history = model.fit(x = x_train, y = y_train, batch_size = 10, epochs = 200, validation_data = (x_test, y_test)
                    , callbacks=[tfb],initial_epoch = 101)
# Out:
# Epoch 102/200
# 3/3 [==============================] - 4s 1s/step - loss: 0.0019 - val_loss: 0.0065
# Epoch 103/200
# 3/3 [==============================] - 3s 1s/step - loss: 0.0015 - val_loss: 0.0050
# Epoch 104/200
# 3/3 [==============================] - 3s 1s/step - loss: 9.9871e-04 - val_loss: 0.0064
# Epoch 105/200
# 3/3 [==============================] - 3s 1s/step - loss: 7.2377e-04 - val_loss: 0.0053
# Epoch 106/200
# 3/3 [==============================] - 3s 1s/step - loss: 6.2090e-04 - val_loss: 0.0058
# Epoch 107/200
# 3/3 [==============================] - 3s 1s/step - loss: 6.0049e-04 - val_loss: 0.0060
# Epoch 108/200
# 3/3 [==============================] - 3s 1s/step - loss: 5.7212e-04 - val_loss: 0.0049
# Epoch 109/200
# 3/3 [==============================] - 3s 1s/step - loss: 2.7158e-04 - val_loss: 0.0060
# Epoch 110/200
# 3/3 [==============================] - 3s 1s/step - loss: 5.4580e-04 - val_loss: 0.0051
# Epoch 111/200
# 3/3 [==============================] - 3s 1s/step - loss: 3.8718e-04 - val_loss: 0.0054
# Epoch 112/200
# 3/3 [==============================] - 3s 1s/step - loss: 3.2138e-04 - val_loss: 0.0052
# Epoch 113/200
# 3/3 [==============================] - 3s 1s/step - loss: 3.5689e-04 - val_loss: 0.0052
# Epoch 114/200
# 3/3 [==============================] - 3s 1s/step - loss: 3.0762e-04 - val_loss: 0.0060
# Epoch 115/200
# 3/3 [==============================] - 3s 1s/step - loss: 5.0542e-04 - val_loss: 0.0050
# Epoch 116/200
# 3/3 [==============================] - 3s 1s/step - loss: 5.8050e-04 - val_loss: 0.0056
# Epoch 117/200
